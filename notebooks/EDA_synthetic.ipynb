# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
base_dir = 'data/synthetic/2-dim/'
next(os.walk(base_dir))[2]
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /Users/milenaangelova/git-repo/EdgeCluster/notebooks/EDA_synthetic.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/Users/milenaangelova/git-repo/EdgeCluster/notebooks/EDA_synthetic.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> base_dir = 'data/synthetic/2-dim/'
# ----> <a href='vscode-notebook-cell:/Users/milenaangelova/git-repo/EdgeCluster/notebooks/EDA_synthetic.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> next(os.walk(base_dir))[2]
#
# StopIteration:

# %%
base_dir = '/data/synthetic/2-dim/'
files = next(os.walk(base_dir))[2]

dfs = []
for file in files:
    dfs.append(pd.read_csv(os.path.join(base_dir, file)))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /Users/milenaangelova/git-repo/EdgeCluster/notebooks/EDA_synthetic.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/Users/milenaangelova/git-repo/EdgeCluster/notebooks/EDA_synthetic.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> base_dir = '/data/synthetic/2-dim/'
# ----> <a href='vscode-notebook-cell:/Users/milenaangelova/git-repo/EdgeCluster/notebooks/EDA_synthetic.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> files = next(os.walk(base_dir))[2]
#       <a href='vscode-notebook-cell:/Users/milenaangelova/git-repo/EdgeCluster/notebooks/EDA_synthetic.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> dfs = []
#       <a href='vscode-notebook-cell:/Users/milenaangelova/git-repo/EdgeCluster/notebooks/EDA_synthetic.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> for file in files:
#
# StopIteration:

# %%
df1 = dfs[0]
df1.head()
