# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
base_dir = '../data/synthetic/2-dim/'

dfs = []
files = next(os.walk(base_dir))[2]

for file in files:
    dfs.append(pd.read_csv(os.path.join(base_dir, file)))

# %%
df1 = dfs[0]
df1.head()
# Out:
#           0         1  cluster
# 0  0.158634  0.570809        1
# 1  0.760156  0.080339        0
# 2  0.978955  0.431564        2
# 3  0.073140  0.060127        4
# 4  0.999277  0.464972        2

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   0        1000 non-null   float64
#  1   1        1000 non-null   float64
#  2   cluster  1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
df1.plot.box()
# Out:
# <Axes: >

# %%
df1.cluster.value_counts()
# Out:
# cluster
# 2    310
# 1    219
# 0    213
# 3    179
# 4     79
# Name: count, dtype: int64

# %%
df1['cluster'].unique()
# Out:
# array([1, 0, 2, 4, 3])

# %%
scatter = plt.scatter(df1["0"], df1["1"], c=df1['cluster'], alpha = 0.6, s=20)
plt.legend(handles=scatter.legend_elements()[0], labels=map(lambda x: 'Cluster ' + str(x), df1['cluster'].unique()))

# %%
for index, df in enumerate(dfs):
    fig, ax = plt.subplots()
    ax.scatter(df["0"], df["1"], c=df['cluster'], alpha = 0.6, s=20)
    ax.legend(handles=scatter.legend_elements()[0], labels=map(lambda x: 'Cluster ' + str(x), df['cluster'].unique()))
    ax.set_title(f"Dataset {index}")
# Out:
# /var/folders/m0/vdxkcl8x2f3g24hptwxr98400000gn/T/ipykernel_21939/1505858126.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
